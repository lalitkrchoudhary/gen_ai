# %% [markdown]
# # Matplotlib is used to visualize the data like PowerBi

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Student Depression Dataset.csv")

# %%
df.sample(5)
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 18917   95792  Female  33.0         Meerut    Student                5.0
# 13305   67512    Male  30.0         Jaipur    Student                5.0
# 26824  135340    Male  33.0         Nashik    Student                3.0
# 6210    31152    Male  22.0         Nagpur    Student                1.0
# 17423   88114  Female  23.0  Visakhapatnam    Student                1.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 18917            0.0  5.12                 3.0               0.0
# 13305            0.0  9.72                 1.0               0.0
# 26824            0.0  7.26                 2.0               0.0
# 6210             0.0  6.25                 3.0               0.0
# 17423            0.0  6.38                 2.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 18917  Less than 5 hours        Healthy       MSc
# ...

# %%
df.shape
# Out:
# (27901, 18)
